# %%
# !pip install google-play-scraper
# Out:
# Collecting google-play-scraper
#   Downloading google_play_scraper-1.2.7-py3-none-any.whl.metadata (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 947.2 kB/s eta 0:00:00
# Downloading google_play_scraper-1.2.7-py3-none-any.whl (28 kB)
# Installing collected packages: google-play-scraper
# Successfully installed google-play-scraper-1.2.7

# %%
from google_play_scraper import app, reviews, Sort, reviews_all
import pandas as pd

# %%
scrapreview = reviews_all(
    'com.levelinfinite.sgameGlobal',
    lang='id',
    country='id',
    sort=Sort.MOST_RELEVANT,
    count=10000
)

# %%
app_reviews_df = pd.DataFrame(scrapreview)
app_reviews_df.shape
app_reviews_df.head()
app_reviews_df.to_csv('ulasan_game_HOK.csv', index=False)

# Membuat dataframe dari hasil scrapreview
app_reviews_df = pd.DataFrame(scrapreview)

# Menghitung jumlah baris dan kolom dalam DataFrame
jumlah_ulasan, jumlah_kolom = app_reviews_df.shape

# %%
app_reviews_df.head()
# Out:
#                                reviewId         userName  \
# 0  502b77c5-d19b-45d2-b07f-f5925b6e235f  Pengguna Google
# 1  5bad4dfb-daa2-4530-b5ba-4bd43e46149f  Pengguna Google
# 2  d31df0ec-1917-4260-bbd7-7bf1305823b6  Pengguna Google
# 3  57661801-2efe-4637-b6d8-24c5d5004972  Pengguna Google
# 4  efa31903-0305-431e-83a3-3e35e0aa8f47  Pengguna Google
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/EGemoI2N...
# 1  https://play-lh.googleusercontent.com/EGemoI2N...
# 2  https://play-lh.googleusercontent.com/EGemoI2N...
# 3  https://play-lh.googleusercontent.com/EGemoI2N...
# 4  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                              content  score  thumbsUpCount  \
# 0  pernah mengalami jaringan tiba tiba hilang pad...      5            125
# 1  dari segi grafik ok enak dilihat game play dal...      3              6
# 2  so far so good, tiap event pasti akan dapat sk...      4              5
# 3  untuk kelas game moba ini cukup bagus tapi moh...      5             39
# 4  saya mau mengkritik",ini game sebenarnya bagus...      1            243
#
#   reviewCreatedVersion                  at  \
# 0             10.5.1.2 2025-07-10 02:46:12
# 1             10.5.1.2 2025-07-10 20:08:27
# 2             10.5.1.2 2025-07-10 12:46:45
# 3             10.5.1.2 2025-07-10 10:00:24
# 4             10.5.1.2 2025-07-10 06:05:12
#
#                                         replyContent           repliedAt  \
# 0                                               None                 NaT
# 1  Terima kasih atas perhatian dan masukan Anda t... 2025-07-11 03:39:21
# 2                                               None                 NaT
# 3                                               None                 NaT
# 4  Kami sangat memahami perasaan Anda. Saat ini, ... 2025-07-10 06:56:17
#
#   appVersion
# 0   10.5.1.2
# 1   10.5.1.2
# 2   10.5.1.2
# 3   10.5.1.2
# 4   10.5.1.2
